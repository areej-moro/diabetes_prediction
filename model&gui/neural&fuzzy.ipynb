# %% [markdown]
# Connected to Python 3.12.5

# %% [markdown]
#  # Diabetes Prediction Model with
#  # Neural Network and Fuzzy Logic

# %% [markdown]
#  # 1-Data Preparation and Neural Network Setup

# %%
import pandas as pd
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, Input
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from sklearn.metrics import (classification_report, roc_auc_score, confusion_matrix, 
                             roc_curve, fbeta_score)
from sklearn.model_selection import KFold
from sklearn.utils.class_weight import compute_class_weight
from imblearn.over_sampling import SMOTE
import matplotlib.pyplot as plt
import seaborn as sns
import skfuzzy as fuzz
from skfuzzy import control as ctrl
from sklearn.preprocessing import StandardScaler

# %%
# Load preprocessed data
try:
    X_train = pd.read_csv('X_train_preprocessed.csv')
    X_test = pd.read_csv('X_test_preprocessed.csv')
    y_train = pd.read_csv('y_train_preprocessed.csv')
    y_test = pd.read_csv('y_test_preprocessed.csv')
except FileNotFoundError as e:
    print(f"Error: {e}. Ensure preprocessed CSV files are in the project directory.")
    exit(1)

# %%
# Load original dataset for fuzzy features (fallback)
try:
    original_data = pd.read_csv('pima-indians-diabetes.data.csv')
except FileNotFoundError as e:
    print(f"Error: {e}. Ensure pima-indians-diabetes.data.csv is in the project directory.")
    exit(1)

# %%
# Convert to numeric and check dtypes
X_train_df = X_train.apply(pd.to_numeric, errors='coerce')  # Keep DataFrame for unscaling
X_test_df = X_test.apply(pd.to_numeric, errors='coerce')  # Keep as DataFrame for feature extraction
y_train = pd.to_numeric(y_train.squeeze(), errors='coerce')
y_test = pd.to_numeric(y_test.squeeze(), errors='coerce')

# %%
# Check for NaN values after conversion
if X_train_df.isna().any().any() or X_test_df.isna().any().any() or y_train.isna().any() or y_test.isna().any():
    print("Error: Non-numeric values found in data. Check CSV files for invalid entries.")
    exit(1)

# %%
# Convert X_train and X_test to numpy arrays for neural network
X_train = X_train_df.values.astype(np.float32)
X_test = X_test_df.values.astype(np.float32)
y_train = y_train.values.astype(np.int32)
y_test = y_test.values.astype(np.int32)

# %%
# Save test set indices for fuzzy alignment
test_indices = X_test_df.index if hasattr(X_test_df, 'index') else np.arange(len(X_test_df))

# %%
# Verify shapes and dtypes
print("X_train shape:", X_train.shape, "dtype:", X_train.dtype)
print("X_test shape:", X_test.shape, "dtype:", X_test.dtype)
print("y_train shape:", y_train.shape, "dtype:", y_train.dtype)
print("y_test shape:", y_test.shape, "dtype:", y_test.dtype)
# Out:
# X_train shape: (696, 10) dtype: float32
# X_test shape: (175, 10) dtype: float32
# y_train shape: (696,) dtype: int32
# y_test shape: (175,) dtype: int32

# %%
# Apply SMOTE with adjusted sampling strategy
smote = SMOTE(random_state=42, sampling_strategy=0.9)
try:
    X_train, y_train = smote.fit_resample(X_train, y_train)
except ValueError as e:
    print(f"Error in SMOTE: {e}. Ensure X_train contains only numeric data.")
    exit(1)
print("X_train shape after SMOTE:", X_train.shape)
print("y_train class distribution after SMOTE:", pd.Series(y_train).value_counts(normalize=True))
# Out:
# X_train shape after SMOTE: (735, 10)
# y_train class distribution after SMOTE: 0    0.526531
# 1    0.473469
# Name: proportion, dtype: float64
# c:\Users\fawzy\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(

# %%
# Compute class weights and adjust for diabetic class
classes = np.unique(y_train)
class_weights = compute_class_weight('balanced', classes=classes, y=y_train)
class_weight_dict = dict(zip(classes, class_weights))
class_weight_dict[1] *= 1.5  # Further increase weight for diabetic class
print("Adjusted class weights:", class_weight_dict)
# Out:
# Adjusted class weights: {np.int32(0): np.float64(0.9496124031007752), np.int32(1): np.float64(1.584051724137931)}

# %%
# Define the enhanced neural network model
def create_model():
    model = Sequential([
        Input(shape=(X_train.shape[1],)),
        Dense(128, activation='relu', kernel_regularizer=l2(0.0001)),
        BatchNormalization(),
        Dropout(0.3),
        Dense(64, activation='relu', kernel_regularizer=l2(0.0001)),
        BatchNormalization(),
        Dropout(0.2),
        Dense(32, activation='relu', kernel_regularizer=l2(0.0001)),
        BatchNormalization(),
        Dropout(0.1),
        Dense(1, activation='sigmoid')
    ])
    optimizer = Adam(learning_rate=0.0005)
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %% [markdown]
#  # 2-Fuzzy Logic System Setup

# %%
# Define fuzzy variables
risk = ctrl.Antecedent(np.arange(0, 1.01, 0.01), 'risk')
glucose = ctrl.Antecedent(np.arange(0, 401, 1), 'glucose')
bmi = ctrl.Antecedent(np.arange(0, 81, 0.5), 'bmi')
blood_pressure = ctrl.Antecedent(np.arange(50, 151, 1), 'blood_pressure')
age = ctrl.Antecedent(np.arange(20, 101, 1), 'age')
output = ctrl.Consequent(np.arange(0, 1.01, 0.01), 'output')

# %%
# Define Membership Functions (refined for Pima dataset distribution)
# Glucose: ~5th=80, 50th=120, 95th=180 mg/dL
glucose['low'] = fuzz.trapmf(glucose.universe, [0, 0, 60, 80])
glucose['normal'] = fuzz.trapmf(glucose.universe, [70, 90, 150, 170])
glucose['high'] = fuzz.trapmf(glucose.universe, [160, 190, 400, 400])

# BMI: ~5th=20, 50th=32, 95th=45
bmi['low'] = fuzz.trapmf(bmi.universe, [0, 0, 18, 22])
bmi['normal'] = fuzz.trapmf(bmi.universe, [18, 23, 33, 38])
bmi['high'] = fuzz.trapmf(bmi.universe, [35, 40, 80, 80])

# BloodPressure: ~5th=60, 50th=80, 95th=110 mmHg
blood_pressure['low'] = fuzz.trapmf(blood_pressure.universe, [50, 50, 55, 65])
blood_pressure['normal'] = fuzz.trapmf(blood_pressure.universe, [60, 70, 90, 100])
blood_pressure['high'] = fuzz.trapmf(blood_pressure.universe, [95, 110, 150, 150])

# Age: ~5th=21, 50th=40, 95th=65
age['young'] = fuzz.trapmf(age.universe, [20, 20, 25, 35])
age['middle'] = fuzz.trapmf(age.universe, [30, 35, 50, 60])
age['old'] = fuzz.trapmf(age.universe, [55, 65, 100, 100])

risk['low'] = fuzz.trapmf(risk.universe, [0, 0, 0.3, 0.4])
risk['medium'] = fuzz.trapmf(risk.universe, [0.35, 0.5, 0.65, 0.75])
risk['high'] = fuzz.trapmf(risk.universe, [0.7, 0.8, 1, 1])

# Adjusted output['low'] to increase low-risk scores
output['low'] = fuzz.trapmf(output.universe, [0, 0, 0.3, 0.4])
output['medium'] = fuzz.trapmf(output.universe, [0.3, 0.45, 0.65, 0.8])
output['high'] = fuzz.trapmf(output.universe, [0.75, 0.85, 1, 1])

# %%
# Define fuzzy rules (expanded and balanced, no weight parameter)
rule1 = ctrl.Rule(risk['high'] & glucose['high'] & bmi['high'], output['high'])
rule2 = ctrl.Rule(risk['high'] & glucose['high'] & bmi['normal'], output['high'])
rule3 = ctrl.Rule(risk['medium'] & glucose['normal'] & bmi['normal'], output['low'])
rule4 = ctrl.Rule(risk['medium'] & glucose['high'] & bmi['high'], output['medium'])
rule5 = ctrl.Rule(risk['low'] & glucose['normal'] & bmi['normal'], output['low'])
rule6 = ctrl.Rule(risk['low'] & glucose['low'] & bmi['low'], output['low'])
rule7 = ctrl.Rule(risk['high'] & glucose['normal'] & bmi['normal'], output['medium'])
rule8 = ctrl.Rule(risk['medium'] & glucose['low'] & bmi['normal'], output['low'])
rule9 = ctrl.Rule(risk['low'] & glucose['high'] & bmi['high'], output['medium'])
rule10 = ctrl.Rule(risk['medium'] & glucose['high'] & bmi['normal'], output['high'])
rule11 = ctrl.Rule(risk['low'] & glucose['high'] & bmi['normal'], output['medium'])
rule12 = ctrl.Rule(risk['high'] & glucose['low'] & bmi['low'], output['medium'])
rule13 = ctrl.Rule(risk['low'] & glucose['low'] & bmi['high'], output['low'])
rule14 = ctrl.Rule(risk['medium'] & glucose['low'] & bmi['high'], output['medium'])
rule15 = ctrl.Rule(risk['high'] & glucose['normal'] & bmi['high'], output['high'])
rule16 = ctrl.Rule(risk['medium'] & glucose['normal'] & bmi['high'], output['medium'])
rule17 = ctrl.Rule(risk['low'] & glucose['normal'] & bmi['high'], output['low'])
rule18 = ctrl.Rule(risk['high'] & glucose['high'] & bmi['low'], output['high'])
rule19 = ctrl.Rule(risk['medium'] & glucose['normal'] & bmi['low'], output['low'])
rule20 = ctrl.Rule(risk['high'] & glucose['low'] & bmi['high'], output['high'])
rule21 = ctrl.Rule(risk['medium'] & glucose['high'] & bmi['low'], output['medium'])
rule22 = ctrl.Rule(risk['low'] & glucose['low'] & bmi['normal'], output['low'])
rule23 = ctrl.Rule(risk['high'] & glucose['normal'] & bmi['low'], output['medium'])
rule24 = ctrl.Rule(risk['medium'] & glucose['low'] & bmi['low'], output['low'])
rule25 = ctrl.Rule(risk['high'] & glucose['high'] & bmi['high'] & blood_pressure['high'], output['high'])
rule26 = ctrl.Rule(risk['medium'] & glucose['normal'] & bmi['normal'] & blood_pressure['low'], output['low'])
rule27 = ctrl.Rule(risk['low'] & glucose['low'] & bmi['low'] & blood_pressure['low'], output['low'])
rule28 = ctrl.Rule(risk['high'] & glucose['normal'] & bmi['normal'] & blood_pressure['low'], output['medium'])
rule29 = ctrl.Rule(risk['medium'] & glucose['low'] & bmi['high'] & blood_pressure['normal'], output['low'])
rule30 = ctrl.Rule(risk['low'] & glucose['high'] & bmi['low'] & blood_pressure['high'], output['medium'])
rule31 = ctrl.Rule(risk['high'] & glucose['high'] & bmi['high'] & age['old'], output['high'])
rule32 = ctrl.Rule(risk['medium'] & glucose['normal'] & bmi['normal'] & age['young'], output['low'])
rule33 = ctrl.Rule(risk['high'] & glucose['high'] & bmi['high'] & blood_pressure['normal'] & age['middle'], output['high'])
rule34 = ctrl.Rule(risk['medium'] & glucose['high'] & bmi['normal'] & blood_pressure['high'], output['high'])
rule35 = ctrl.Rule(risk['medium'] & glucose['high'] & bmi['high'] & age['old'], output['high'])
rule36 = ctrl.Rule(risk['high'] & glucose['normal'] & bmi['high'] & blood_pressure['high'], output['high'])
rule37 = ctrl.Rule(risk['low'] & glucose['low'] & bmi['normal'] & blood_pressure['normal'] & age['young'], output['low'])
rule38 = ctrl.Rule(risk['medium'] & glucose['normal'] & bmi['low'] & blood_pressure['low'], output['low'])
rule39 = ctrl.Rule(risk['high'] & glucose['high'] & bmi['high'] & blood_pressure['high'] & age['middle'], output['high'])
# Non-diabetic rules (duplicated to mimic weight=1.5)
rule40 = ctrl.Rule(glucose['low'] & bmi['low'] & blood_pressure['low'] & age['young'], output['low'])
rule41 = ctrl.Rule(glucose['normal'] & bmi['normal'] & blood_pressure['normal'] & age['young'], output['low'])
rule42 = ctrl.Rule(glucose['normal'] & bmi['low'] & blood_pressure['low'] & age['middle'], output['low'])
rule43 = ctrl.Rule(glucose['high'] & bmi['high'] & blood_pressure['high'] & age['old'], output['high'])
rule44 = ctrl.Rule(glucose['normal'] & bmi['normal'] & blood_pressure['high'] & age['middle'], output['medium'])
rule45 = ctrl.Rule(glucose['low'] & bmi['normal'] & blood_pressure['normal'] & age['middle'], output['low'])
# Duplicate non-diabetic rules to increase influence
rule46 = ctrl.Rule(glucose['low'] & bmi['low'] & blood_pressure['low'] & age['young'], output['low'])
rule47 = ctrl.Rule(glucose['normal'] & bmi['normal'] & blood_pressure['normal'] & age['young'], output['low'])
rule48 = ctrl.Rule(glucose['normal'] & bmi['low'] & blood_pressure['low'] & age['middle'], output['low'])

# %%
# Create fuzzy system
fuzzy_system = ctrl.ControlSystem([rule1, rule2, rule3, rule4, rule5, rule6, rule7, rule8, rule9, rule10, 
                                   rule11, rule12, rule13, rule14, rule15, rule16, rule17, rule18, rule19, 
                                   rule20, rule21, rule22, rule23, rule24, rule25, rule26, rule27, rule28, 
                                   rule29, rule30, rule31, rule32, rule33, rule34, rule35, rule36, rule37, 
                                   rule38, rule39, rule40, rule41, rule42, rule43, rule44, rule45, rule46, 
                                   rule47, rule48])
fuzzy_simulation = ctrl.ControlSystemSimulation(fuzzy_system)

# %%
# Fuzzy prediction function
def predict_risk(nn_risk, glucose_val, bmi_val, blood_pressure_val, age_val):
    try:
        fuzzy_simulation.input['risk'] = nn_risk
        fuzzy_simulation.input['glucose'] = glucose_val
        fuzzy_simulation.input['bmi'] = bmi_val
        fuzzy_simulation.input['blood_pressure'] = blood_pressure_val
        fuzzy_simulation.input['age'] = age_val
        fuzzy_simulation.compute()
        risk_score = fuzzy_simulation.output.get('output', 0.5)
        if risk_score <= 0.35:
            risk_label = "Low Risk"
        elif risk_score <= 0.8:
            risk_label = "Medium Risk"
        else:
            risk_label = "High Risk"
        return risk_score, risk_label
    except Exception as e:
        print(f"Error in fuzzy computation: {e}. Using default values.")
        return 0.5, "Medium Risk"

# %% [markdown]
#  # 3-Model Training and Evaluation

# %%
# Perform k-fold cross-validation
kfold = KFold(n_splits=5, shuffle=True, random_state=42)
cv_scores = []

for fold, (train_idx, val_idx) in enumerate(kfold.split(X_train, y_train)):
    print(f"\nFold {fold + 1}")
    X_train_fold = X_train[train_idx]
    y_train_fold = y_train[train_idx]
    X_val_fold = X_train[val_idx]
    y_val_fold = y_train[val_idx]

    # Verify fold dtypes
    print(f"Fold {fold + 1} X_train_fold dtype:", X_train_fold.dtype)
    print(f"Fold {fold + 1} y_train_fold dtype:", y_train_fold.dtype)

    # Create and train model
    try:
        model = create_model()
    except Exception as e:
        print(f"Error creating model in fold {fold + 1}: {e}")
        exit(1)

    early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
    lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=0.00001)
    try:
        history = model.fit(
            X_train_fold, y_train_fold,
            epochs=300,
            batch_size=16,
            validation_data=(X_val_fold, y_val_fold),
            class_weight=class_weight_dict,
            callbacks=[early_stopping, lr_scheduler],
            verbose=1
        )
    except Exception as e:
        print(f"Error during training in fold {fold + 1}: {e}")
        exit(1)

    # Evaluate on validation fold
    try:
        val_loss, val_accuracy = model.evaluate(X_val_fold, y_val_fold, verbose=0)
        cv_scores.append(val_accuracy)
        print(f"Fold {fold + 1} Validation Accuracy: {val_accuracy:.4f}")
    except Exception as e:
        print(f"Error evaluating model in fold {fold + 1}: {e}")
        exit(1)

print(f"\nCross-Validation Accuracy: {np.mean(cv_scores):.4f} ± {np.std(cv_scores):.4f}")
# Out:
# Fold 1
# Fold 1 X_train_fold dtype: float32
# Fold 1 y_train_fold dtype: int32
# Epoch 1/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.5928 - loss: 0.9046 - val_accuracy: 0.6803 - val_loss: 0.6574 - learning_rate: 5.0000e-04
# Epoch 2/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7321 - loss: 0.6468 - val_accuracy: 0.5986 - val_loss: 0.6609 - learning_rate: 5.0000e-04
# Epoch 3/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7071 - loss: 0.6533 - val_accuracy: 0.5918 - val_loss: 0.6699 - learning_rate: 5.0000e-04
# Epoch 4/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7218 - loss: 0.6523 - val_accuracy: 0.6122 - val_loss: 0.6660 - learning_rate: 5.0000e-04
# Epoch 5/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7703 - loss: 0.5759 - val_accuracy: 0.6327 - val_loss: 0.6605 - learning_rate: 5.0000e-04
# Epoch 6/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7979 - loss: 0.5493 - val_accuracy: 0.6327 - val_loss: 0.6509 - learning_rate: 5.0000e-04
# Epoch 7/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7285 - loss: 0.6641 - val_accuracy: 0.6395 - val_loss: 0.6446 - learning_rate: 5.0000e-04
# Epoch 8/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7909 - loss: 0.5697 - val_accuracy: 0.6395 - val_loss: 0.6601 - learning_rate: 5.0000e-04
# Epoch 9/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7669 - loss: 0.6094 - val_accuracy: 0.6599 - val_loss: 0.6411 - learning_rate: 5.0000e-04
# Epoch 10/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7385 - loss: 0.6759 - val_accuracy: 0.6667 - val_loss: 0.6524 - learning_rate: 5.0000e-04
# Epoch 11/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7253 - loss: 0.6228 - val_accuracy: 0.6667 - val_loss: 0.6431 - learning_rate: 5.0000e-04
# Epoch 12/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7481 - loss: 0.6351 - val_accuracy: 0.6599 - val_loss: 0.6328 - learning_rate: 5.0000e-04
# Epoch 13/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8064 - loss: 0.5767 - val_accuracy: 0.6871 - val_loss: 0.6356 - learning_rate: 5.0000e-04
# Epoch 14/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7778 - loss: 0.5493 - val_accuracy: 0.6735 - val_loss: 0.6426 - learning_rate: 5.0000e-04
# Epoch 15/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7767 - loss: 0.5370 - val_accuracy: 0.6735 - val_loss: 0.6341 - learning_rate: 5.0000e-04
# Epoch 16/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8322 - loss: 0.4719 - val_accuracy: 0.6735 - val_loss: 0.6335 - learning_rate: 5.0000e-04
# Epoch 17/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7847 - loss: 0.5354 - val_accuracy: 0.6803 - val_loss: 0.6352 - learning_rate: 5.0000e-04
# Epoch 18/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8022 - loss: 0.5039 - val_accuracy: 0.6803 - val_loss: 0.6375 - learning_rate: 2.5000e-04
# Epoch 19/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7988 - loss: 0.5389 - val_accuracy: 0.6871 - val_loss: 0.6360 - learning_rate: 2.5000e-04
# Epoch 20/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7863 - loss: 0.5628 - val_accuracy: 0.6803 - val_loss: 0.6392 - learning_rate: 2.5000e-04
# Epoch 21/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8103 - loss: 0.5343 - val_accuracy: 0.6871 - val_loss: 0.6346 - learning_rate: 2.5000e-04
# Epoch 22/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7700 - loss: 0.5802 - val_accuracy: 0.6803 - val_loss: 0.6342 - learning_rate: 2.5000e-04
# Epoch 23/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8134 - loss: 0.5202 - val_accuracy: 0.6735 - val_loss: 0.6422 - learning_rate: 1.2500e-04
# Epoch 24/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7721 - loss: 0.5436 - val_accuracy: 0.6803 - val_loss: 0.6443 - learning_rate: 1.2500e-04
# Epoch 25/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7894 - loss: 0.5571 - val_accuracy: 0.6803 - val_loss: 0.6457 - learning_rate: 1.2500e-04
# Epoch 26/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8231 - loss: 0.4710 - val_accuracy: 0.6803 - val_loss: 0.6482 - learning_rate: 1.2500e-04
# Epoch 27/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8131 - loss: 0.5250 - val_accuracy: 0.6735 - val_loss: 0.6496 - learning_rate: 1.2500e-04
# Epoch 28/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7661 - loss: 0.5978 - val_accuracy: 0.6803 - val_loss: 0.6498 - learning_rate: 6.2500e-05
# Epoch 29/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7852 - loss: 0.5610 - val_accuracy: 0.6803 - val_loss: 0.6490 - learning_rate: 6.2500e-05
# Epoch 30/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7813 - loss: 0.5446 - val_accuracy: 0.6735 - val_loss: 0.6443 - learning_rate: 6.2500e-05
# Epoch 31/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7828 - loss: 0.5551 - val_accuracy: 0.6735 - val_loss: 0.6448 - learning_rate: 6.2500e-05
# Epoch 32/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8139 - loss: 0.5171 - val_accuracy: 0.6735 - val_loss: 0.6441 - learning_rate: 6.2500e-05
# Fold 1 Validation Accuracy: 0.6599
#
# Fold 2
# Fold 2 X_train_fold dtype: float32
# Fold 2 y_train_fold dtype: int32
# Epoch 1/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.5260 - loss: 1.0571 - val_accuracy: 0.7483 - val_loss: 0.6329 - learning_rate: 5.0000e-04
# Epoch 2/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6787 - loss: 0.7271 - val_accuracy: 0.7143 - val_loss: 0.5907 - learning_rate: 5.0000e-04
# Epoch 3/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7037 - loss: 0.7137 - val_accuracy: 0.6939 - val_loss: 0.5762 - learning_rate: 5.0000e-04
# Epoch 4/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7471 - loss: 0.6521 - val_accuracy: 0.6803 - val_loss: 0.5747 - learning_rate: 5.0000e-04
# Epoch 5/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7514 - loss: 0.6328 - val_accuracy: 0.7007 - val_loss: 0.5709 - learning_rate: 5.0000e-04
# Epoch 6/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7128 - loss: 0.6745 - val_accuracy: 0.7075 - val_loss: 0.5570 - learning_rate: 5.0000e-04
# Epoch 7/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7411 - loss: 0.6077 - val_accuracy: 0.7143 - val_loss: 0.5499 - learning_rate: 5.0000e-04
# Epoch 8/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7181 - loss: 0.6661 - val_accuracy: 0.7143 - val_loss: 0.5372 - learning_rate: 5.0000e-04
# Epoch 9/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7234 - loss: 0.6787 - val_accuracy: 0.7075 - val_loss: 0.5265 - learning_rate: 5.0000e-04
# Epoch 10/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7588 - loss: 0.6168 - val_accuracy: 0.7279 - val_loss: 0.5185 - learning_rate: 5.0000e-04
# Epoch 11/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7877 - loss: 0.5650 - val_accuracy: 0.7279 - val_loss: 0.5171 - learning_rate: 5.0000e-04
# Epoch 12/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7756 - loss: 0.6200 - val_accuracy: 0.7551 - val_loss: 0.4992 - learning_rate: 5.0000e-04
# Epoch 13/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7554 - loss: 0.5744 - val_accuracy: 0.7551 - val_loss: 0.4913 - learning_rate: 5.0000e-04
# Epoch 14/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7490 - loss: 0.5954 - val_accuracy: 0.7551 - val_loss: 0.4960 - learning_rate: 5.0000e-04
# Epoch 15/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7879 - loss: 0.5600 - val_accuracy: 0.7687 - val_loss: 0.4912 - learning_rate: 5.0000e-04
# Epoch 16/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7373 - loss: 0.6215 - val_accuracy: 0.7755 - val_loss: 0.4942 - learning_rate: 5.0000e-04
# Epoch 17/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7766 - loss: 0.5913 - val_accuracy: 0.7755 - val_loss: 0.4900 - learning_rate: 5.0000e-04
# Epoch 18/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7645 - loss: 0.6195 - val_accuracy: 0.7823 - val_loss: 0.4873 - learning_rate: 5.0000e-04
# Epoch 19/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8177 - loss: 0.5272 - val_accuracy: 0.7687 - val_loss: 0.4906 - learning_rate: 5.0000e-04
# Epoch 20/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7674 - loss: 0.5850 - val_accuracy: 0.7687 - val_loss: 0.4839 - learning_rate: 5.0000e-04
# Epoch 21/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7667 - loss: 0.6147 - val_accuracy: 0.7959 - val_loss: 0.4811 - learning_rate: 5.0000e-04
# Epoch 22/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7542 - loss: 0.5763 - val_accuracy: 0.7755 - val_loss: 0.4757 - learning_rate: 5.0000e-04
# Epoch 23/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7695 - loss: 0.5650 - val_accuracy: 0.7755 - val_loss: 0.4728 - learning_rate: 5.0000e-04
# Epoch 24/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7637 - loss: 0.5554 - val_accuracy: 0.7891 - val_loss: 0.4776 - learning_rate: 5.0000e-04
# Epoch 25/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7569 - loss: 0.5936 - val_accuracy: 0.7823 - val_loss: 0.4747 - learning_rate: 5.0000e-04
# Epoch 26/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7853 - loss: 0.5455 - val_accuracy: 0.7823 - val_loss: 0.4680 - learning_rate: 5.0000e-04
# Epoch 27/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7961 - loss: 0.5721 - val_accuracy: 0.7891 - val_loss: 0.4716 - learning_rate: 5.0000e-04
# Epoch 28/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7978 - loss: 0.5582 - val_accuracy: 0.7687 - val_loss: 0.4698 - learning_rate: 5.0000e-04
# Epoch 29/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8049 - loss: 0.5172 - val_accuracy: 0.7755 - val_loss: 0.4702 - learning_rate: 5.0000e-04
# Epoch 30/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7791 - loss: 0.5367 - val_accuracy: 0.7755 - val_loss: 0.4686 - learning_rate: 5.0000e-04
# Epoch 31/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7921 - loss: 0.5619 - val_accuracy: 0.7823 - val_loss: 0.4675 - learning_rate: 5.0000e-04
# Epoch 32/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8025 - loss: 0.5324 - val_accuracy: 0.7755 - val_loss: 0.4715 - learning_rate: 5.0000e-04
# Epoch 33/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7845 - loss: 0.5694 - val_accuracy: 0.7619 - val_loss: 0.4689 - learning_rate: 5.0000e-04
# Epoch 34/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7792 - loss: 0.5504 - val_accuracy: 0.7619 - val_loss: 0.4731 - learning_rate: 5.0000e-04
# Epoch 35/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7807 - loss: 0.5631 - val_accuracy: 0.7551 - val_loss: 0.4672 - learning_rate: 5.0000e-04
# Epoch 36/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7984 - loss: 0.5068 - val_accuracy: 0.7687 - val_loss: 0.4780 - learning_rate: 5.0000e-04
# Epoch 37/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7901 - loss: 0.5673 - val_accuracy: 0.7891 - val_loss: 0.4769 - learning_rate: 5.0000e-04
# Epoch 38/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8023 - loss: 0.5303 - val_accuracy: 0.7755 - val_loss: 0.4733 - learning_rate: 5.0000e-04
# Epoch 39/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7796 - loss: 0.5760 - val_accuracy: 0.7687 - val_loss: 0.4718 - learning_rate: 5.0000e-04
# Epoch 40/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7854 - loss: 0.5437 - val_accuracy: 0.7891 - val_loss: 0.4705 - learning_rate: 5.0000e-04
# Epoch 41/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8206 - loss: 0.5402 - val_accuracy: 0.7823 - val_loss: 0.4708 - learning_rate: 2.5000e-04
# Epoch 42/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8126 - loss: 0.4950 - val_accuracy: 0.7687 - val_loss: 0.4698 - learning_rate: 2.5000e-04
# Epoch 43/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8186 - loss: 0.5208 - val_accuracy: 0.7687 - val_loss: 0.4716 - learning_rate: 2.5000e-04
# Epoch 44/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7907 - loss: 0.5489 - val_accuracy: 0.7687 - val_loss: 0.4706 - learning_rate: 2.5000e-04
# Epoch 45/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8149 - loss: 0.5031 - val_accuracy: 0.7687 - val_loss: 0.4713 - learning_rate: 2.5000e-04
# Epoch 46/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8334 - loss: 0.4824 - val_accuracy: 0.7755 - val_loss: 0.4691 - learning_rate: 1.2500e-04
# Epoch 47/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7989 - loss: 0.5114 - val_accuracy: 0.7755 - val_loss: 0.4690 - learning_rate: 1.2500e-04
# Epoch 48/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8257 - loss: 0.4627 - val_accuracy: 0.7755 - val_loss: 0.4683 - learning_rate: 1.2500e-04
# Epoch 49/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7937 - loss: 0.5866 - val_accuracy: 0.7619 - val_loss: 0.4696 - learning_rate: 1.2500e-04
# Epoch 50/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8082 - loss: 0.5055 - val_accuracy: 0.7755 - val_loss: 0.4683 - learning_rate: 1.2500e-04
# Epoch 51/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8100 - loss: 0.5110 - val_accuracy: 0.7755 - val_loss: 0.4689 - learning_rate: 6.2500e-05
# Epoch 52/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7944 - loss: 0.5184 - val_accuracy: 0.7687 - val_loss: 0.4674 - learning_rate: 6.2500e-05
# Epoch 53/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8025 - loss: 0.4979 - val_accuracy: 0.7687 - val_loss: 0.4697 - learning_rate: 6.2500e-05
# Epoch 54/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8064 - loss: 0.5184 - val_accuracy: 0.7687 - val_loss: 0.4690 - learning_rate: 6.2500e-05
# Epoch 55/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7970 - loss: 0.5025 - val_accuracy: 0.7755 - val_loss: 0.4714 - learning_rate: 6.2500e-05
# Fold 2 Validation Accuracy: 0.7551
#
# Fold 3
# Fold 3 X_train_fold dtype: float32
# Fold 3 y_train_fold dtype: int32
# Epoch 1/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4932 - loss: 1.0575 - val_accuracy: 0.7143 - val_loss: 0.6469 - learning_rate: 5.0000e-04
# Epoch 2/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6741 - loss: 0.7640 - val_accuracy: 0.7619 - val_loss: 0.6069 - learning_rate: 5.0000e-04
# Epoch 3/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6945 - loss: 0.7013 - val_accuracy: 0.7619 - val_loss: 0.5798 - learning_rate: 5.0000e-04
# Epoch 4/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6961 - loss: 0.6600 - val_accuracy: 0.7551 - val_loss: 0.5639 - learning_rate: 5.0000e-04
# Epoch 5/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7498 - loss: 0.6200 - val_accuracy: 0.7619 - val_loss: 0.5544 - learning_rate: 5.0000e-04
# Epoch 6/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7349 - loss: 0.6185 - val_accuracy: 0.7551 - val_loss: 0.5529 - learning_rate: 5.0000e-04
# Epoch 7/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7560 - loss: 0.5523 - val_accuracy: 0.7347 - val_loss: 0.5503 - learning_rate: 5.0000e-04
# Epoch 8/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7942 - loss: 0.5539 - val_accuracy: 0.7347 - val_loss: 0.5652 - learning_rate: 5.0000e-04
# Epoch 9/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7406 - loss: 0.5913 - val_accuracy: 0.7483 - val_loss: 0.5621 - learning_rate: 5.0000e-04
# Epoch 10/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7743 - loss: 0.5474 - val_accuracy: 0.7483 - val_loss: 0.5639 - learning_rate: 5.0000e-04
# Epoch 11/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7770 - loss: 0.6109 - val_accuracy: 0.7347 - val_loss: 0.5657 - learning_rate: 5.0000e-04
# Epoch 12/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7291 - loss: 0.6389 - val_accuracy: 0.7347 - val_loss: 0.5573 - learning_rate: 5.0000e-04
# Epoch 13/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7408 - loss: 0.6245 - val_accuracy: 0.7415 - val_loss: 0.5556 - learning_rate: 2.5000e-04
# Epoch 14/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7624 - loss: 0.5822 - val_accuracy: 0.7551 - val_loss: 0.5581 - learning_rate: 2.5000e-04
# Epoch 15/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7647 - loss: 0.5682 - val_accuracy: 0.7347 - val_loss: 0.5620 - learning_rate: 2.5000e-04
# Epoch 16/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7793 - loss: 0.5794 - val_accuracy: 0.7347 - val_loss: 0.5620 - learning_rate: 2.5000e-04
# Epoch 17/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7707 - loss: 0.5706 - val_accuracy: 0.7347 - val_loss: 0.5618 - learning_rate: 2.5000e-04
# Epoch 18/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7890 - loss: 0.5870 - val_accuracy: 0.7415 - val_loss: 0.5610 - learning_rate: 1.2500e-04
# Epoch 19/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7870 - loss: 0.5476 - val_accuracy: 0.7415 - val_loss: 0.5615 - learning_rate: 1.2500e-04
# Epoch 20/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8024 - loss: 0.5216 - val_accuracy: 0.7347 - val_loss: 0.5610 - learning_rate: 1.2500e-04
# Epoch 21/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8022 - loss: 0.5018 - val_accuracy: 0.7347 - val_loss: 0.5607 - learning_rate: 1.2500e-04
# Epoch 22/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7771 - loss: 0.5830 - val_accuracy: 0.7347 - val_loss: 0.5560 - learning_rate: 1.2500e-04
# Epoch 23/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7330 - loss: 0.5824 - val_accuracy: 0.7347 - val_loss: 0.5548 - learning_rate: 6.2500e-05
# Epoch 24/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7534 - loss: 0.5910 - val_accuracy: 0.7347 - val_loss: 0.5555 - learning_rate: 6.2500e-05
# Epoch 25/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7507 - loss: 0.6037 - val_accuracy: 0.7347 - val_loss: 0.5552 - learning_rate: 6.2500e-05
# Epoch 26/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8198 - loss: 0.5074 - val_accuracy: 0.7347 - val_loss: 0.5555 - learning_rate: 6.2500e-05
# Epoch 27/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7847 - loss: 0.5620 - val_accuracy: 0.7347 - val_loss: 0.5547 - learning_rate: 6.2500e-05
# Fold 3 Validation Accuracy: 0.7347
#
# Fold 4
# Fold 4 X_train_fold dtype: float32
# Fold 4 y_train_fold dtype: int32
# Epoch 1/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.6348 - loss: 0.8801 - val_accuracy: 0.7279 - val_loss: 0.6503 - learning_rate: 5.0000e-04
# Epoch 2/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7244 - loss: 0.6846 - val_accuracy: 0.6667 - val_loss: 0.6315 - learning_rate: 5.0000e-04
# Epoch 3/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7128 - loss: 0.6596 - val_accuracy: 0.6395 - val_loss: 0.6306 - learning_rate: 5.0000e-04
# Epoch 4/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7605 - loss: 0.6591 - val_accuracy: 0.6667 - val_loss: 0.6067 - learning_rate: 5.0000e-04
# Epoch 5/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7731 - loss: 0.6091 - val_accuracy: 0.6803 - val_loss: 0.6011 - learning_rate: 5.0000e-04
# Epoch 6/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7555 - loss: 0.6613 - val_accuracy: 0.6735 - val_loss: 0.5976 - learning_rate: 5.0000e-04
# Epoch 7/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7106 - loss: 0.6634 - val_accuracy: 0.7211 - val_loss: 0.5520 - learning_rate: 5.0000e-04
# Epoch 8/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7499 - loss: 0.6546 - val_accuracy: 0.7483 - val_loss: 0.5395 - learning_rate: 5.0000e-04
# Epoch 9/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7495 - loss: 0.5839 - val_accuracy: 0.7687 - val_loss: 0.5243 - learning_rate: 5.0000e-04
# Epoch 10/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7211 - loss: 0.6440 - val_accuracy: 0.7619 - val_loss: 0.5125 - learning_rate: 5.0000e-04
# Epoch 11/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7444 - loss: 0.6356 - val_accuracy: 0.7755 - val_loss: 0.5073 - learning_rate: 5.0000e-04
# Epoch 12/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7629 - loss: 0.6038 - val_accuracy: 0.7687 - val_loss: 0.5027 - learning_rate: 5.0000e-04
# Epoch 13/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7580 - loss: 0.6049 - val_accuracy: 0.7619 - val_loss: 0.4923 - learning_rate: 5.0000e-04
# Epoch 14/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7696 - loss: 0.6294 - val_accuracy: 0.7755 - val_loss: 0.4928 - learning_rate: 5.0000e-04
# Epoch 15/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7487 - loss: 0.5813 - val_accuracy: 0.7823 - val_loss: 0.4919 - learning_rate: 5.0000e-04
# Epoch 16/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7671 - loss: 0.5726 - val_accuracy: 0.7959 - val_loss: 0.4900 - learning_rate: 5.0000e-04
# Epoch 17/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7641 - loss: 0.6046 - val_accuracy: 0.7891 - val_loss: 0.4804 - learning_rate: 5.0000e-04
# Epoch 18/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7399 - loss: 0.6068 - val_accuracy: 0.7891 - val_loss: 0.4908 - learning_rate: 5.0000e-04
# Epoch 19/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7463 - loss: 0.6459 - val_accuracy: 0.7755 - val_loss: 0.4975 - learning_rate: 5.0000e-04
# Epoch 20/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7544 - loss: 0.6234 - val_accuracy: 0.7823 - val_loss: 0.4930 - learning_rate: 5.0000e-04
# Epoch 21/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7812 - loss: 0.5757 - val_accuracy: 0.7823 - val_loss: 0.5068 - learning_rate: 5.0000e-04
# Epoch 22/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7474 - loss: 0.6040 - val_accuracy: 0.7687 - val_loss: 0.5103 - learning_rate: 5.0000e-04
# Epoch 23/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7456 - loss: 0.5992 - val_accuracy: 0.7755 - val_loss: 0.5100 - learning_rate: 2.5000e-04
# Epoch 24/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7678 - loss: 0.5801 - val_accuracy: 0.7755 - val_loss: 0.5070 - learning_rate: 2.5000e-04
# Epoch 25/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7307 - loss: 0.5914 - val_accuracy: 0.7823 - val_loss: 0.5066 - learning_rate: 2.5000e-04
# Epoch 26/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7644 - loss: 0.5792 - val_accuracy: 0.7823 - val_loss: 0.5037 - learning_rate: 2.5000e-04
# Epoch 27/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7446 - loss: 0.5817 - val_accuracy: 0.7891 - val_loss: 0.5009 - learning_rate: 2.5000e-04
# Epoch 28/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7842 - loss: 0.5773 - val_accuracy: 0.7959 - val_loss: 0.4980 - learning_rate: 1.2500e-04
# Epoch 29/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7807 - loss: 0.5646 - val_accuracy: 0.7959 - val_loss: 0.4948 - learning_rate: 1.2500e-04
# Epoch 30/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7749 - loss: 0.5607 - val_accuracy: 0.7959 - val_loss: 0.4964 - learning_rate: 1.2500e-04
# Epoch 31/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7807 - loss: 0.5571 - val_accuracy: 0.7959 - val_loss: 0.4959 - learning_rate: 1.2500e-04
# Epoch 32/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7319 - loss: 0.5852 - val_accuracy: 0.7959 - val_loss: 0.4958 - learning_rate: 1.2500e-04
# Epoch 33/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7614 - loss: 0.5855 - val_accuracy: 0.7959 - val_loss: 0.4957 - learning_rate: 6.2500e-05
# Epoch 34/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7893 - loss: 0.5263 - val_accuracy: 0.7891 - val_loss: 0.4964 - learning_rate: 6.2500e-05
# Epoch 35/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7892 - loss: 0.5226 - val_accuracy: 0.7959 - val_loss: 0.4971 - learning_rate: 6.2500e-05
# Epoch 36/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7780 - loss: 0.5167 - val_accuracy: 0.7959 - val_loss: 0.4954 - learning_rate: 6.2500e-05
# Epoch 37/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7873 - loss: 0.5752 - val_accuracy: 0.7959 - val_loss: 0.4954 - learning_rate: 6.2500e-05
# Fold 4 Validation Accuracy: 0.7891
#
# Fold 5
# Fold 5 X_train_fold dtype: float32
# Fold 5 y_train_fold dtype: int32
# Epoch 1/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.5105 - loss: 1.0589 - val_accuracy: 0.6463 - val_loss: 0.6578 - learning_rate: 5.0000e-04
# Epoch 2/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6564 - loss: 0.8261 - val_accuracy: 0.6463 - val_loss: 0.6396 - learning_rate: 5.0000e-04
# Epoch 3/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7026 - loss: 0.7067 - val_accuracy: 0.7007 - val_loss: 0.6098 - learning_rate: 5.0000e-04
# Epoch 4/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7234 - loss: 0.7064 - val_accuracy: 0.7687 - val_loss: 0.5774 - learning_rate: 5.0000e-04
# Epoch 5/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7348 - loss: 0.6765 - val_accuracy: 0.8163 - val_loss: 0.5527 - learning_rate: 5.0000e-04
# Epoch 6/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7404 - loss: 0.7056 - val_accuracy: 0.8027 - val_loss: 0.5274 - learning_rate: 5.0000e-04
# Epoch 7/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7245 - loss: 0.7189 - val_accuracy: 0.8231 - val_loss: 0.4968 - learning_rate: 5.0000e-04
# Epoch 8/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7330 - loss: 0.6685 - val_accuracy: 0.8299 - val_loss: 0.4738 - learning_rate: 5.0000e-04
# Epoch 9/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7848 - loss: 0.5855 - val_accuracy: 0.8095 - val_loss: 0.4646 - learning_rate: 5.0000e-04
# Epoch 10/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7275 - loss: 0.6282 - val_accuracy: 0.8163 - val_loss: 0.4495 - learning_rate: 5.0000e-04
# Epoch 11/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7181 - loss: 0.6603 - val_accuracy: 0.8163 - val_loss: 0.4462 - learning_rate: 5.0000e-04
# Epoch 12/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7396 - loss: 0.6143 - val_accuracy: 0.8095 - val_loss: 0.4400 - learning_rate: 5.0000e-04
# Epoch 13/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7582 - loss: 0.6606 - val_accuracy: 0.8163 - val_loss: 0.4394 - learning_rate: 5.0000e-04
# Epoch 14/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7306 - loss: 0.7122 - val_accuracy: 0.8027 - val_loss: 0.4367 - learning_rate: 5.0000e-04
# Epoch 15/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7566 - loss: 0.6046 - val_accuracy: 0.8095 - val_loss: 0.4367 - learning_rate: 5.0000e-04
# Epoch 16/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7489 - loss: 0.6537 - val_accuracy: 0.8163 - val_loss: 0.4255 - learning_rate: 5.0000e-04
# Epoch 17/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7830 - loss: 0.5753 - val_accuracy: 0.8095 - val_loss: 0.4300 - learning_rate: 5.0000e-04
# Epoch 18/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7830 - loss: 0.6101 - val_accuracy: 0.8163 - val_loss: 0.4374 - learning_rate: 5.0000e-04
# Epoch 19/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7892 - loss: 0.5472 - val_accuracy: 0.8095 - val_loss: 0.4305 - learning_rate: 5.0000e-04
# Epoch 20/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7591 - loss: 0.5981 - val_accuracy: 0.8095 - val_loss: 0.4232 - learning_rate: 5.0000e-04
# Epoch 21/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7929 - loss: 0.5791 - val_accuracy: 0.8095 - val_loss: 0.4201 - learning_rate: 5.0000e-04
# Epoch 22/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7855 - loss: 0.5362 - val_accuracy: 0.8163 - val_loss: 0.4171 - learning_rate: 5.0000e-04
# Epoch 23/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7870 - loss: 0.5345 - val_accuracy: 0.8095 - val_loss: 0.4188 - learning_rate: 5.0000e-04
# Epoch 24/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7567 - loss: 0.5929 - val_accuracy: 0.8095 - val_loss: 0.4198 - learning_rate: 5.0000e-04
# Epoch 25/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8065 - loss: 0.5548 - val_accuracy: 0.8163 - val_loss: 0.4178 - learning_rate: 5.0000e-04
# Epoch 26/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7865 - loss: 0.5798 - val_accuracy: 0.8095 - val_loss: 0.4135 - learning_rate: 5.0000e-04
# Epoch 27/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7804 - loss: 0.5638 - val_accuracy: 0.8231 - val_loss: 0.4130 - learning_rate: 5.0000e-04
# Epoch 28/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7746 - loss: 0.5483 - val_accuracy: 0.8163 - val_loss: 0.4151 - learning_rate: 5.0000e-04
# Epoch 29/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8087 - loss: 0.5231 - val_accuracy: 0.8163 - val_loss: 0.4206 - learning_rate: 5.0000e-04
# Epoch 30/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7879 - loss: 0.5577 - val_accuracy: 0.8027 - val_loss: 0.4130 - learning_rate: 5.0000e-04
# Epoch 31/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7755 - loss: 0.5929 - val_accuracy: 0.8027 - val_loss: 0.4134 - learning_rate: 5.0000e-04
# Epoch 32/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7426 - loss: 0.6213 - val_accuracy: 0.8095 - val_loss: 0.4101 - learning_rate: 5.0000e-04
# Epoch 33/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7875 - loss: 0.5380 - val_accuracy: 0.8095 - val_loss: 0.4051 - learning_rate: 5.0000e-04
# Epoch 34/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7833 - loss: 0.5809 - val_accuracy: 0.8163 - val_loss: 0.4050 - learning_rate: 5.0000e-04
# Epoch 35/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7751 - loss: 0.6008 - val_accuracy: 0.8163 - val_loss: 0.4154 - learning_rate: 5.0000e-04
# Epoch 36/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7465 - loss: 0.6048 - val_accuracy: 0.8231 - val_loss: 0.4085 - learning_rate: 5.0000e-04
# Epoch 37/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7529 - loss: 0.5972 - val_accuracy: 0.8231 - val_loss: 0.4138 - learning_rate: 5.0000e-04
# Epoch 38/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7800 - loss: 0.5252 - val_accuracy: 0.8231 - val_loss: 0.4092 - learning_rate: 5.0000e-04
# Epoch 39/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7774 - loss: 0.5692 - val_accuracy: 0.8095 - val_loss: 0.4116 - learning_rate: 2.5000e-04
# Epoch 40/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7995 - loss: 0.5450 - val_accuracy: 0.8095 - val_loss: 0.4110 - learning_rate: 2.5000e-04
# Epoch 41/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8205 - loss: 0.4844 - val_accuracy: 0.8163 - val_loss: 0.4078 - learning_rate: 2.5000e-04
# Epoch 42/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7666 - loss: 0.6018 - val_accuracy: 0.8163 - val_loss: 0.4100 - learning_rate: 2.5000e-04
# Epoch 43/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7855 - loss: 0.5288 - val_accuracy: 0.8299 - val_loss: 0.4075 - learning_rate: 2.5000e-04
# Epoch 44/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7992 - loss: 0.5177 - val_accuracy: 0.8231 - val_loss: 0.4074 - learning_rate: 1.2500e-04
# Epoch 45/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7934 - loss: 0.5581 - val_accuracy: 0.8299 - val_loss: 0.4072 - learning_rate: 1.2500e-04
# Epoch 46/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7941 - loss: 0.5323 - val_accuracy: 0.8299 - val_loss: 0.4083 - learning_rate: 1.2500e-04
# Epoch 47/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7842 - loss: 0.5180 - val_accuracy: 0.8299 - val_loss: 0.4078 - learning_rate: 1.2500e-04
# Epoch 48/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7791 - loss: 0.5602 - val_accuracy: 0.8299 - val_loss: 0.4079 - learning_rate: 1.2500e-04
# Epoch 49/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8331 - loss: 0.4980 - val_accuracy: 0.8231 - val_loss: 0.4076 - learning_rate: 6.2500e-05
# Epoch 50/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8150 - loss: 0.4936 - val_accuracy: 0.8299 - val_loss: 0.4059 - learning_rate: 6.2500e-05
# Epoch 51/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7828 - loss: 0.5512 - val_accuracy: 0.8231 - val_loss: 0.4063 - learning_rate: 6.2500e-05
# Epoch 52/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7746 - loss: 0.5454 - val_accuracy: 0.8231 - val_loss: 0.4066 - learning_rate: 6.2500e-05
# Epoch 53/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7921 - loss: 0.5222 - val_accuracy: 0.8299 - val_loss: 0.4058 - learning_rate: 6.2500e-05
# Epoch 54/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7961 - loss: 0.5337 - val_accuracy: 0.8231 - val_loss: 0.4066 - learning_rate: 3.1250e-05
# Fold 5 Validation Accuracy: 0.8163
#
# Cross-Validation Accuracy: 0.7510 ± 0.0535

# %%
# Train final model on full training data
try:
    model = create_model()
    print("Final model created successfully.")
except Exception as e:
    print(f"Error creating final model: {e}")
    exit(1)

early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=0.00001)
try:
    history = model.fit(
        X_train, y_train,
        epochs=300,
        batch_size=16,
        validation_data=(X_test, y_test),
        class_weight=class_weight_dict,
        callbacks=[early_stopping, lr_scheduler],
        verbose=1
    )
    print("Final model training completed.")
except Exception as e:
    print(f"Error training final model: {e}")
    exit(1)
# Out:
# Final model created successfully.
# Epoch 1/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.5527 - loss: 1.0684 - val_accuracy: 0.7371 - val_loss: 0.6291 - learning_rate: 5.0000e-04
# Epoch 2/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7061 - loss: 0.7323 - val_accuracy: 0.6971 - val_loss: 0.6069 - learning_rate: 5.0000e-04
# Epoch 3/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7137 - loss: 0.6349 - val_accuracy: 0.6914 - val_loss: 0.5922 - learning_rate: 5.0000e-04
# Epoch 4/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7208 - loss: 0.6464 - val_accuracy: 0.6743 - val_loss: 0.5954 - learning_rate: 5.0000e-04
# Epoch 5/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7289 - loss: 0.6623 - val_accuracy: 0.6914 - val_loss: 0.5766 - learning_rate: 5.0000e-04
# Epoch 6/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7326 - loss: 0.6864 - val_accuracy: 0.7143 - val_loss: 0.5532 - learning_rate: 5.0000e-04
# Epoch 7/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7484 - loss: 0.6268 - val_accuracy: 0.7314 - val_loss: 0.5323 - learning_rate: 5.0000e-04
# Epoch 8/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7793 - loss: 0.5723 - val_accuracy: 0.7486 - val_loss: 0.5160 - learning_rate: 5.0000e-04
# Epoch 9/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7525 - loss: 0.6381 - val_accuracy: 0.7429 - val_loss: 0.5133 - learning_rate: 5.0000e-04
# Epoch 10/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7456 - loss: 0.6171 - val_accuracy: 0.7429 - val_loss: 0.5121 - learning_rate: 5.0000e-04
# Epoch 11/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7638 - loss: 0.6088 - val_accuracy: 0.7600 - val_loss: 0.5093 - learning_rate: 5.0000e-04
# Epoch 12/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7679 - loss: 0.5962 - val_accuracy: 0.7771 - val_loss: 0.4865 - learning_rate: 5.0000e-04
# Epoch 13/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8092 - loss: 0.5458 - val_accuracy: 0.7714 - val_loss: 0.4929 - learning_rate: 5.0000e-04
# Epoch 14/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7257 - loss: 0.5910 - val_accuracy: 0.7771 - val_loss: 0.4874 - learning_rate: 5.0000e-04
# Epoch 15/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7713 - loss: 0.5723 - val_accuracy: 0.7771 - val_loss: 0.4806 - learning_rate: 5.0000e-04
# Epoch 16/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7923 - loss: 0.5666 - val_accuracy: 0.7771 - val_loss: 0.4748 - learning_rate: 5.0000e-04
# Epoch 17/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8005 - loss: 0.5283 - val_accuracy: 0.7657 - val_loss: 0.4806 - learning_rate: 5.0000e-04
# Epoch 18/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7888 - loss: 0.5214 - val_accuracy: 0.7714 - val_loss: 0.4799 - learning_rate: 5.0000e-04
# Epoch 19/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7717 - loss: 0.5509 - val_accuracy: 0.7714 - val_loss: 0.4914 - learning_rate: 5.0000e-04
# Epoch 20/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7886 - loss: 0.5499 - val_accuracy: 0.7657 - val_loss: 0.4938 - learning_rate: 5.0000e-04
# Epoch 21/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7856 - loss: 0.6174 - val_accuracy: 0.7771 - val_loss: 0.4841 - learning_rate: 5.0000e-04
# Epoch 22/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7913 - loss: 0.5560 - val_accuracy: 0.7714 - val_loss: 0.4761 - learning_rate: 2.5000e-04
# Epoch 23/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7849 - loss: 0.5293 - val_accuracy: 0.7771 - val_loss: 0.4720 - learning_rate: 2.5000e-04
# Epoch 24/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7787 - loss: 0.5262 - val_accuracy: 0.7886 - val_loss: 0.4736 - learning_rate: 2.5000e-04
# Epoch 25/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8159 - loss: 0.5359 - val_accuracy: 0.7771 - val_loss: 0.4715 - learning_rate: 2.5000e-04
# Epoch 26/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7746 - loss: 0.5691 - val_accuracy: 0.7829 - val_loss: 0.4699 - learning_rate: 2.5000e-04
# Epoch 27/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7953 - loss: 0.5435 - val_accuracy: 0.7829 - val_loss: 0.4680 - learning_rate: 2.5000e-04
# Epoch 28/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7947 - loss: 0.5297 - val_accuracy: 0.7714 - val_loss: 0.4737 - learning_rate: 2.5000e-04
# Epoch 29/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7582 - loss: 0.6104 - val_accuracy: 0.7771 - val_loss: 0.4733 - learning_rate: 2.5000e-04
# Epoch 30/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8126 - loss: 0.5124 - val_accuracy: 0.7771 - val_loss: 0.4759 - learning_rate: 2.5000e-04
# Epoch 31/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7832 - loss: 0.5590 - val_accuracy: 0.7829 - val_loss: 0.4785 - learning_rate: 2.5000e-04
# Epoch 32/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7835 - loss: 0.5700 - val_accuracy: 0.7771 - val_loss: 0.4814 - learning_rate: 2.5000e-04
# Epoch 33/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7730 - loss: 0.5683 - val_accuracy: 0.7829 - val_loss: 0.4783 - learning_rate: 1.2500e-04
# Epoch 34/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7846 - loss: 0.5113 - val_accuracy: 0.7829 - val_loss: 0.4768 - learning_rate: 1.2500e-04
# Epoch 35/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8404 - loss: 0.4815 - val_accuracy: 0.7829 - val_loss: 0.4812 - learning_rate: 1.2500e-04
# Epoch 36/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7663 - loss: 0.5577 - val_accuracy: 0.7771 - val_loss: 0.4797 - learning_rate: 1.2500e-04
# Epoch 37/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7863 - loss: 0.5333 - val_accuracy: 0.7829 - val_loss: 0.4777 - learning_rate: 1.2500e-04
# Epoch 38/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7906 - loss: 0.5315 - val_accuracy: 0.7829 - val_loss: 0.4777 - learning_rate: 6.2500e-05
# Epoch 39/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7683 - loss: 0.5383 - val_accuracy: 0.7829 - val_loss: 0.4769 - learning_rate: 6.2500e-05
# Epoch 40/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8066 - loss: 0.5154 - val_accuracy: 0.7829 - val_loss: 0.4767 - learning_rate: 6.2500e-05
# Epoch 41/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7765 - loss: 0.5460 - val_accuracy: 0.7771 - val_loss: 0.4767 - learning_rate: 6.2500e-05
# Epoch 42/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7796 - loss: 0.5460 - val_accuracy: 0.7829 - val_loss: 0.4772 - learning_rate: 6.2500e-05
# Epoch 43/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7613 - loss: 0.5343 - val_accuracy: 0.7714 - val_loss: 0.4780 - learning_rate: 3.1250e-05
# Epoch 44/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8058 - loss: 0.5593 - val_accuracy: 0.7771 - val_loss: 0.4775 - learning_rate: 3.1250e-05
# Epoch 45/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7919 - loss: 0.5410 - val_accuracy: 0.7829 - val_loss: 0.4777 - learning_rate: 3.1250e-05
# Epoch 46/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8192 - loss: 0.5199 - val_accuracy: 0.7771 - val_loss: 0.4753 - learning_rate: 3.1250e-05
# Epoch 47/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7595 - loss: 0.5693 - val_accuracy: 0.7771 - val_loss: 0.4752 - learning_rate: 3.1250e-05
# Final model training completed.

# %%
# Evaluate on test set
try:
    test_loss, test_accuracy = model.evaluate(X_test, y_test)
    print(f"\nFinal Test Accuracy (Neural Network): {test_accuracy:.4f}")
except Exception as e:
    print(f"Error evaluating final model: {e}")
    exit(1)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7797 - loss: 0.4806
#
# Final Test Accuracy (Neural Network): 0.7829

# %%
# Get neural network predictions
try:
    y_pred_prob = model.predict(X_test)
    print("Neural network predictions generated successfully.")
except Exception as e:
    print(f"Error generating predictions: {e}")
    exit(1)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Neural network predictions generated successfully.

# %%
# Extract fuzzy features from preprocessed X_test_df
required_columns = ['Glucose', 'BMI', 'BloodPressure', 'Age']
# Debug: Print column names to diagnose unscaling issue
print("X_train_df columns:", X_train_df.columns.tolist())
print("X_test_df columns:", X_test_df.columns.tolist())

# Map possible column names (Pima dataset may use different names)
column_mapping = {
    'Glucose': ['Glucose', 'glucose', '2'],
    'BMI': ['BMI', 'bmi', '6'],
    'BloodPressure': ['BloodPressure', 'bloodpressure', '3'],
    'Age': ['Age', 'age', '7']
}
selected_columns = []
for req_col in required_columns:
    for possible_col in column_mapping[req_col]:
        if possible_col in X_test_df.columns:
            selected_columns.append(possible_col)
            break
    else:
        print(f"Error: No matching column for {req_col} in X_test_df")
        selected_columns.append(None)

if all(col is not None for col in selected_columns) and all(col in X_train_df.columns for col in selected_columns):
    # Unscale fuzzy features
    scaler = StandardScaler()
    try:
        scaler.fit(X_train_df[selected_columns])
        fuzzy_features = scaler.inverse_transform(X_test_df[selected_columns])
        print("Fuzzy features unscaled successfully.")
    except Exception as e:
        print(f"Error unscaling fuzzy features: {e}")
        print("Falling back to original dataset.")
        try:
            # Map original dataset columns (Pima uses numeric indices)
            orig_columns = {
                'Glucose': '2',
                'BMI': '6',
                'BloodPressure': '3',
                'Age': '7'
            }
            orig_selected = [orig_columns[col] for col in required_columns]
            if not all(idx in original_data.index for idx in test_indices):
                print("Error: test_indices do not align with original_data indices")
                exit(1)
            fuzzy_features = original_data.loc[test_indices, orig_selected].values
        except KeyError as e:
            print(f"Error accessing original dataset: {e}")
            exit(1)
else:
    print("Warning: Required columns not found in X_test_df. Falling back to original dataset.")
    try:
        orig_columns = {
            'Glucose': '2',
            'BMI': '6',
            'BloodPressure': '3',
            'Age': '7'
        }
        orig_selected = [orig_columns[col] for col in required_columns]
        if not all(idx in original_data.index for idx in test_indices):
            print("Error: test_indices do not align with original_data indices")
            exit(1)
        fuzzy_features = original_data.loc[test_indices, orig_selected].values
    except KeyError as e:
        print(f"Error accessing original dataset: {e}")
        exit(1)

glucose_vals = fuzzy_features[:, 0]
bmi_vals = fuzzy_features[:, 1]
blood_pressure_vals = fuzzy_features[:, 2]
age_vals = fuzzy_features[:, 3]

# Debug: Print feature ranges
print("Glucose range:", glucose_vals.min(), glucose_vals.max())
print("BMI range:", bmi_vals.min(), bmi_vals.max())
print("BloodPressure range:", blood_pressure_vals.min(), blood_pressure_vals.max())
print("Age range:", age_vals.min(), age_vals.max())
# Out:
# X_train_df columns: ['Pregnancies', 'Age', 'BloodPressure', 'Insulin', 'Insulin_Pedigree', 'SkinThickness', 'Log_Insulin', 'Glucose', 'Glucose_BMI', 'BMI']
# X_test_df columns: ['Pregnancies', 'Age', 'BloodPressure', 'Insulin', 'Insulin_Pedigree', 'SkinThickness', 'Log_Insulin', 'Glucose', 'Glucose_BMI', 'BMI']
# Fuzzy features unscaled successfully.
# Glucose range: -1.760733821388778 2.5636728369864685
# BMI range: -2.2789505594820985 2.674540628071887
# BloodPressure range: -2.2202433109776893 2.1236281955278953
# Age range: -1.1193287153346856 4.255286296458328

# %%
# Clip and handle NaN values (adjusted for unscaled ranges)
glucose_vals = np.clip(glucose_vals, 0, 400)
bmi_vals = np.clip(bmi_vals, 0, 80)
blood_pressure_vals = np.clip(blood_pressure_vals, 50, 150)
age_vals = np.clip(age_vals, 20, 100)
glucose_vals = np.nan_to_num(glucose_vals, nan=120)
bmi_vals = np.nan_to_num(bmi_vals, nan=25)
blood_pressure_vals = np.nan_to_num(blood_pressure_vals, nan=90)
age_vals = np.nan_to_num(age_vals, nan=40)

# %%
# Apply fuzzy system
fuzzy_results = []
for i in range(len(y_pred_prob)):
    nn_risk = y_pred_prob[i][0]
    glucose_val = glucose_vals[i]
    bmi_val = bmi_vals[i]
    blood_pressure_val = blood_pressure_vals[i]
    age_val = age_vals[i]
    risk_score, risk_label = predict_risk(nn_risk, glucose_val, bmi_val, blood_pressure_val, age_val)
    fuzzy_results.append({
        'Index': test_indices[i] if isinstance(test_indices, np.ndarray) else test_indices[i],
        'True_Label': y_test[i],
        'NN_Probability': nn_risk,
        'Fuzzy_Risk_Score': risk_score,
        'Fuzzy_Risk_Label': risk_label,
        'Glucose': glucose_val,
        'BMI': bmi_val,
        'BloodPressure': blood_pressure_val,
        'Age': age_val
    })

# %%
# Convert fuzzy results to DataFrame
results_df = pd.DataFrame(fuzzy_results)

# %%
# Debug: Print fuzzy risk score distribution
print("Fuzzy Risk Score Distribution:")
print(results_df['Fuzzy_Risk_Score'].describe())
# Out:
# Fuzzy Risk Score Distribution:
# count    175.000000
# mean       0.246425
# std        0.088521
# min        0.176190
# 25%        0.176190
# 50%        0.176190
# 75%        0.363382
# max        0.363382
# Name: Fuzzy_Risk_Score, dtype: float64

# %%
# Optimize threshold for fuzzy predictions with F1-score
thresholds = np.arange(0.2, 0.81, 0.01)
best_threshold = 0.5
best_f1_score = 0
for t in thresholds:
    fuzzy_pred = (results_df['Fuzzy_Risk_Score'] > t).astype(int)
    f1 = fbeta_score(y_test, fuzzy_pred, beta=1)
    if f1 > best_f1_score:
        best_f1_score = f1
        best_threshold = t
print(f"Best Fuzzy Threshold (F1-score): {best_threshold:.4f}, F1-score: {best_f1_score:.4f}")
# Out:
# Best Fuzzy Threshold (F1-score): 0.2700, F1-score: 0.7448

# %%
# Generate fuzzy predictions with best threshold
fuzzy_pred = (results_df['Fuzzy_Risk_Score'] > best_threshold).astype(int)

# %%
# Ensemble predictions (adjusted weights)
combined_score = 0.8 * results_df['NN_Probability'] + 0.2 * results_df['Fuzzy_Risk_Score']
combined_pred = (combined_score > 0.6).astype(int)

# %%
# Evaluate neural network predictions
nn_threshold = 0.6
y_pred_nn = (y_pred_prob > nn_threshold).astype(int)
print("\nNeural Network Classification Report:")
print(classification_report(y_test, y_pred_nn, target_names=['Non-Diabetic', 'Diabetic']))
nn_roc_auc = roc_auc_score(y_test, y_pred_prob)
print(f"Neural Network ROC-AUC: {nn_roc_auc:.4f}")
# Out:
# Neural Network Classification Report:
#               precision    recall  f1-score   support
#
# Non-Diabetic       0.83      0.79      0.81        97
#     Diabetic       0.76      0.79      0.78        78
#
#     accuracy                           0.79       175
#    macro avg       0.79      0.79      0.79       175
# weighted avg       0.80      0.79      0.79       175
#
# Neural Network ROC-AUC: 0.8759

# %%
# Evaluate fuzzy predictions
print("\nFuzzy System Classification Report:")
print(classification_report(y_test, fuzzy_pred, target_names=['Non-Diabetic', 'Diabetic']))
fuzzy_roc_auc = roc_auc_score(y_test, results_df['Fuzzy_Risk_Score'])
print(f"Fuzzy System ROC-AUC: {fuzzy_roc_auc:.4f}")
# Out:
# Fuzzy System Classification Report:
#               precision    recall  f1-score   support
#
# Non-Diabetic       0.78      0.87      0.82        97
#     Diabetic       0.81      0.69      0.74        78
#
#     accuracy                           0.79       175
#    macro avg       0.79      0.78      0.78       175
# weighted avg       0.79      0.79      0.79       175
#
# Fuzzy System ROC-AUC: 0.7858

# %%
# Evaluate ensemble predictions
print("\nEnsemble (Neural + Fuzzy) Classification Report:")
print(classification_report(y_test, combined_pred, target_names=['Non-Diabetic', 'Diabetic']))
combined_roc_auc = roc_auc_score(y_test, combined_score)
print(f"Ensemble ROC-AUC: {combined_roc_auc:.4f}")
# Out:
# Ensemble (Neural + Fuzzy) Classification Report:
#               precision    recall  f1-score   support
#
# Non-Diabetic       0.78      0.85      0.81        97
#     Diabetic       0.79      0.71      0.74        78
#
#     accuracy                           0.78       175
#    macro avg       0.78      0.78      0.78       175
# weighted avg       0.78      0.78      0.78       175
#
# Ensemble ROC-AUC: 0.8759

# %%
# Check correlation and fuzzy score stats
correlation = results_df['NN_Probability'].corr(results_df['Fuzzy_Risk_Score'])
print(f"Correlation between NN_Probability and Fuzzy_Risk_Score: {correlation:.4f}")
print("Fuzzy_Risk_Score Stats: Min =", results_df['Fuzzy_Risk_Score'].min(), 
      "Max =", results_df['Fuzzy_Risk_Score'].max(), 
      "Mean =", results_df['Fuzzy_Risk_Score'].mean())
# Out:
# Correlation between NN_Probability and Fuzzy_Risk_Score: 0.8415
# Fuzzy_Risk_Score Stats: Min = 0.17619047619047615 Max = 0.36338235294117655 Mean = 0.24642480802064853

# %%
# Save predictions
results_df['NN_Predicted'] = y_pred_nn.flatten()
results_df['Fuzzy_Predicted'] = fuzzy_pred
results_df['Combined_Predicted'] = combined_pred
results_df.to_csv('combined_predictions.csv', index=False)
print("Combined predictions saved to combined_predictions.csv")
# Out:
# Combined predictions saved to combined_predictions.csv

# %%
# Visualize neural vs fuzzy
plt.figure(figsize=(10, 6))
sns.scatterplot(data=results_df, x='NN_Probability', y='Fuzzy_Risk_Score', hue='Fuzzy_Risk_Label', style='True_Label')
plt.axhline(y=0.35, color='gray', linestyle='--', alpha=0.5)
plt.axhline(y=0.8, color='gray', linestyle='--', alpha=0.5)
plt.title('Neural Network Probability vs Fuzzy Risk Score')
plt.xlabel('Neural Network Probability')
plt.ylabel('Fuzzy Risk Score')
plt.grid(True)
plt.savefig('neural_vs_fuzzy.png')
plt.close()
print("Neural vs Fuzzy comparison plot saved to neural_vs_fuzzy.png")
# Out:
# Neural vs Fuzzy comparison plot saved to neural_vs_fuzzy.png

# %%
# Fuzzy score distribution
plt.figure(figsize=(8, 6))
sns.histplot(data=results_df, x='Fuzzy_Risk_Score', hue='True_Label', bins=30)
plt.title('Fuzzy Risk Score Distribution by True Label')
plt.savefig('fuzzy_score_distribution.png')
plt.close()
print("Fuzzy score distribution saved to fuzzy_score_distribution.png")
# Out:
# Fuzzy score distribution saved to fuzzy_score_distribution.png

# %%
# Confusion matrix for fuzzy predictions
cm_fuzzy = confusion_matrix(y_test, fuzzy_pred)
plt.figure(figsize=(6, 4))
sns.heatmap(cm_fuzzy, annot=True, fmt='d', cmap='Blues', 
            xticklabels=['Non-Diabetic', 'Diabetic'], yticklabels=['Non-Diabetic', 'Diabetic'])
plt.title('Fuzzy System Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.savefig('confusion_matrix_fuzzy.png')
plt.close()
print("Fuzzy confusion matrix saved to confusion_matrix_fuzzy.png")
# Out:
# Fuzzy confusion matrix saved to confusion_matrix_fuzzy.png

# %%
# Confusion matrix for neural network
cm_nn = confusion_matrix(y_test, y_pred_nn)
plt.figure(figsize=(6, 4))
sns.heatmap(cm_nn, annot=True, fmt='d', cmap='Blues', 
            xticklabels=['Non-Diabetic', 'Diabetic'], yticklabels=['Non-Diabetic', 'Diabetic'])
plt.title('Neural Network Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.savefig('confusion_matrix_nn.png')
plt.close()
print("Neural network confusion matrix saved to confusion_matrix_nn.png")
# Out:
# Neural network confusion matrix saved to confusion_matrix_nn.png

# %%
# Confusion matrix for ensemble
cm_combined = confusion_matrix(y_test, combined_pred)
plt.figure(figsize=(6, 4))
sns.heatmap(cm_combined, annot=True, fmt='d', cmap='Blues', 
            xticklabels=['Non-Diabetic', 'Diabetic'], yticklabels=['Non-Diabetic', 'Diabetic'])
plt.title('Ensemble (Neural + Fuzzy) Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.savefig('confusion_matrix_combined.png')
plt.close()
print("Ensemble confusion matrix saved to confusion_matrix_combined.png")
# Out:
# Ensemble confusion matrix saved to confusion_matrix_combined.png

# %%
# Plot training history
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.savefig('training_history.png')
plt.close()
print("Training history plot saved to training_history.png")
# Out:
# Training history plot saved to training_history.png

# %%
# Save the model
model.save('diabetes_nn_model_enhanced.keras')
print("Model saved to diabetes_nn_model_enhanced.keras")
